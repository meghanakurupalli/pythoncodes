# %% [markdown]
# # <u> **Part 1: Data Processing** </u>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/Users/megha/Scripts/datasets/DataScienceRepository/winequality-white.csv', sep=";")

# %%
print("Solutions 1 and 2")
df.head()
# Out:
# Solutions 1 and 2
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# ...

# %%
X = df['quality']
X.shape
# Out:
# (4898,)

# %%
df['quality'].describe()
# Out:
# count    4898.000000
# mean        5.877909
# std         0.885639
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         9.000000
# Name: quality, dtype: float64

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
X = df.iloc[:, 0:11]
y = (df["quality"]>5).astype(np.int)
#(df["quality"]>5).astype(np.int)
df["quality"] = np.where(df["quality"]>5, 1, 0)
print("SOlution 3")
#print(X)
#print(y)
print(df)
# Out:
# SOlution 3
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36           20.70      0.045
# 1               6.3             0.300         0.34            1.60      0.049
# 2               8.1             0.280         0.40            6.90      0.050
# 3               7.2             0.230         0.32            8.50      0.058
# 4               7.2             0.230         0.32            8.50      0.058
# 5               8.1             0.280         0.40            6.90      0.050
# 6               6.2             0.320         0.16            7.00      0.045
# 7               7.0             0.270         0.36           20.70      0.045
# 8               6.3             0.300         0.34            1.60      0.049
# 9               8.1             0.220         0.43            1.50      0.044
# 10              8.1             0.270         0.41            1.45      0.033
# ...

# %%
X.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
for col in X.columns:
    
        print('\nColumn Name:', col,)
        print(X[col].value_counts())
# Out:
# Column Name: fixed acidity
# 6.80     308
# 6.60     290
# 6.40     280
# 6.90     241
# 6.70     236
# 7.00     232
# 6.50     225
# 7.20     206
# 7.10     200
# 7.40     194
# 6.20     192
# 6.30     188
# 6.00     184
# 7.30     178
# 6.10     155
# 7.60     153
# 7.50     123
# 5.80     121
# 5.90     103
# 7.80      93
# 7.70      93
# 5.70      88
# 8.00      80
# 7.90      74
# 5.60      71
# 8.20      56
# 8.10      56
# 8.30      52
# 8.40      35
# 8.50      32
#         ...
# 8.80      18
# 9.00      17
# 8.90      16
# 8.70      15
# 9.40      11
# 4.80       9
# 9.80       8
# 4.90       7
# 9.10       6
# 4.70       5
# 9.60       5
# 9.70       4
# 10.00      3
# 4.40       3
# 9.30       3
# 9.90       2
# 7.15       2
# 6.15       2
# 10.70      2
# 9.50       2
# 4.20       2
# 10.30      2
# 4.60       1
# 11.80      1
# 4.50       1
# 6.45       1
# 3.80       1
# 14.20      1
# 10.20      1
# 3.90       1
# Name: fixed acidity, Length: 68, dtype: int64
#
# ...

# %%
df.corr()['quality'].sort_values(ascending=False)
# Out:
# quality                 1.000000
# alcohol                 0.383280
# pH                      0.083687
# sulphates               0.051858
# citric acid            -0.000700
# free sulfur dioxide    -0.001278
# fixed acidity          -0.089749
# residual sugar         -0.092756
# total sulfur dioxide   -0.170924
# chlorides              -0.183939
# volatile acidity       -0.225440
# density                -0.268696
# Name: quality, dtype: float64

# %%
from pandas.tools.plotting import scatter_matrix

attributes = ["quality", "fixed acidity", "volatile acidity", "citric acid", "residual sugar", "chlorides", "free sulfur dioxide","total sulfur dioxide", "density", "pH", "sulphates", "alcohol"]

scatter_matrix(df[attributes], figsize=(30, 20))
# Out:
# c:\users\megha\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   """
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000018095DB5630>,
# ...
#       dtype=object)

# %%
most_correlated = df.corr().abs()['quality'].sort_values(ascending=False)


# Maintain the top 7 most correlation features with Grade
most_correlated = most_correlated[:8]

print("Most Correlated Features:\n")
print(most_correlated)
# Out:
# Most Correlated Features:
#
# quality                 1.000000
# alcohol                 0.383280
# density                 0.268696
# volatile acidity        0.225440
# chlorides               0.183939
# total sulfur dioxide    0.170924
# residual sugar          0.092756
# fixed acidity           0.089749
# Name: quality, dtype: float64

# %%
# Matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
from scipy import stats

# Calculate correlation coefficient
print("Solution 6")
def corrfunc(x, y, **kws):
    r, _ = stats.pearsonr(x, y)
    ax = plt.gca()
    ax.annotate("r = {:.2f}".format(r),
                xy=(.1, .6), xycoords=ax.transAxes,
               size = 24)
    
cmap = sns.cubehelix_palette(light=1, dark = 0.1,
                             hue = 0.5, as_cmap=True)

sns.set_context(font_scale=2)

# Pair grid set up
g = sns.PairGrid(df)

# Scatter plot on the upper triangle
g.map_upper(plt.scatter, s=10, color = 'red')

# Distribution on the diagonal
g.map_diag(sns.distplot, kde=False, color = 'red')

# Density Plot and Correlation coefficients on the lower triangle
g.map_lower(sns.kdeplot, cmap = cmap)
g.map_lower(corrfunc);
# Out:
# Solution 6

# %%
# Since citric acid and free sulfur dioxide have very similar correlation values, we can drop one of them. Dropping free sulfur dioxide:
print("Solution 7")
df.drop(["free sulfur dioxide"], axis = 1)
# Out:
# Solution 7
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36           20.70      0.045
# 1               6.3             0.300         0.34            1.60      0.049
# 2               8.1             0.280         0.40            6.90      0.050
# 3               7.2             0.230         0.32            8.50      0.058
# 4               7.2             0.230         0.32            8.50      0.058
# 5               8.1             0.280         0.40            6.90      0.050
# 6               6.2             0.320         0.16            7.00      0.045
# 7               7.0             0.270         0.36           20.70      0.045
# 8               6.3             0.300         0.34            1.60      0.049
# 9               8.1             0.220         0.43            1.50      0.044
# 10              8.1             0.270         0.41            1.45      0.033
# ...

# %%
#Splitting data into train and test data(Solution 8)

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.8, random_state=0)

# %%
#Standardizing each feature of train and test datasets

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)

scaler = StandardScaler().fit(X_test)
X_test = scaler.transform(X_test)

# %%
print(X_test)
# Out:
# [[ 0.51590684  0.41632127  0.12529562 ...  0.34792153 -0.6053045
#    0.14926329]
#  [ 0.16513673  0.31647958 -0.6115003  ... -0.37998671 -0.2548427
#   -0.58254333]
#  [ 0.86667695 -1.38082925  3.31807796 ... -0.77702757 -0.7805354
#    0.23057514]
#  ...
#  [ 0.39898347  1.21505484 -0.77523273 ...  0.08322763  0.27085001
#   -1.07041441]
#  [-0.41948012  1.61442163  1.27142262 ... -0.51233366 -1.04338175
#   -1.47697364]
#  [ 0.04821336  0.91552976 -0.85709894 ...  0.28174805 -0.6053045
#   -0.41991963]]

# %%
print(X_train)
# Out:
# [[-0.55135562  1.18161019 -1.22251787 ...  0.18852722  0.41331358
#    1.7795724 ]
#  [-0.42572379  2.24697859 -0.70659935 ...  0.58744974  0.6765187
#    0.04951924]
#  [-2.56146489 -1.43338497 -0.1046944  ...  1.51826895  1.29066396
#    1.04970622]
#  ...
#  [ 1.33312181  0.50364848 -0.44864008 ... -0.27688238 -0.99044703
#   -1.38318104]
#  [ 2.58944011 -0.17431322 -0.01870798 ... -0.40985655 -0.28856672
#    0.2387438 ]
#  [ 1.33312181  2.24697859  0.06727845 ... -0.6758049   0.15010847
#   -0.41002613]]

# %% [markdown]
# # <u> **Part 2: Model Evaluation** </u>

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# The param_grid tells Scikit-Learn to first evaluate all 50 × 2 = 100 combinations of 
#   n_neighbors and p hyperparameter values specified in the dict
print("Solution 10")

param_grid = {'n_neighbors': [1, 3, 5, 7, 9, 15, 21, 23, 33, 35, 37], 'p': [1, 2, 10, 100], 'weights': ["uniform", "distance"]}

knn = KNeighborsClassifier()

knn_cv = GridSearchCV(knn, param_grid, scoring='f1', cv=10)
knn_cv.fit(X_train, y_train)

print("Best Score: %f" % knn_cv.best_score_)
print("Optimal Hyperparameter Values: ", knn_cv.best_params_)
# Out:
# Solution 10
# Best Score: 0.835351
# Optimal Hyperparameter Values:  {'n_neighbors': 35, 'p': 2, 'weights': 'distance'}

# %%
from sklearn.neighbors import KNeighborsClassifier

print("Solution 11")
knn = KNeighborsClassifier(weights="uniform", algorithm='auto', n_neighbors=35, p=2)
knn.fit(X_train, y_train)
# Out:
# Solution 11
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=35, p=2,
#            weights='uniform')

# %%
from sklearn.model_selection import cross_val_score

# Scoring Parameter for Classification:
# https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter
# Note: For a skewed data set "accuracy" might not be a good choice for scoring
print("Solution 12")

scores = cross_val_score(knn, X_train, y_train, scoring='f1', cv=10)
print(scores)

print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Solution 12
# [0.81081081 0.83333333 0.8057554  0.78571429 0.82517483 0.86896552
#  0.78832117 0.84507042 0.80291971 0.84671533]
# Accuracy: 0.82 (+/- 0.05)

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix

print("Solution 13")
y_train_pred = cross_val_predict(knn, X_train, y_train, cv=3)

confusion_matrix(y_train, y_train_pred)
# Out:
# Solution 13
# array([[123, 199],
#        [ 82, 575]], dtype=int64)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

print("solution 13")
precision = precision_score(y_train, y_train_pred) 
print("Precision = %f" % precision)

recall = recall_score(y_train, y_train_pred)
print("Recall = %f" % recall)


f1 = f1_score(y_train, y_train_pred)
print("F1 Score = %f" % f1)
# Out:
# solution 13
# Precision = 0.742894
# Recall = 0.875190
# F1 Score = 0.803634

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import roc_curve


# Get the 2nd column of the matrix of predicted probabilities for each data point
#    The 2nd column stores the probalities of the positive class
y_scores = cross_val_predict(knn, X_train, y_train, method="predict_proba", cv=10)[:, 1]


fpr, tpr, thresholds = roc_curve(y_train, y_scores)

print("\nFPR FPR & TPR for Various Threshold Values:")

print("FPR: ", fpr)
print("TPR: ", tpr)
print("\nThresholds: ", thresholds)
# Out:
# FPR FPR & TPR for Various Threshold Values:
# FPR:  [0.         0.         0.00621118 0.01242236 0.02173913 0.03416149
#  0.04968944 0.07453416 0.10559006 0.13043478 0.16770186 0.20807453
#  0.24223602 0.28881988 0.3447205  0.37888199 0.43478261 0.49378882
#  0.54347826 0.59937888 0.68322981 0.76397516 0.82298137 0.87267081
#  0.91925466 0.95341615 0.98136646 0.99689441 1.         1.        ]
# TPR:  [0.         0.06849315 0.15372907 0.22678843 0.29832572 0.36225266
#  0.39117199 0.44444444 0.49010654 0.55098935 0.59817352 0.64687976
#  0.68797565 0.72907154 0.75799087 0.79299848 0.82039574 0.85844749
#  0.88280061 0.89802131 0.92846271 0.94063927 0.95585997 0.97412481
#  0.98173516 0.98934551 0.99391172 0.99543379 0.99847793 1.        ]
#
# Thresholds:  [2.         1.         0.97142857 0.94285714 0.91428571 0.88571429
#  0.85714286 0.82857143 0.8        0.77142857 0.74285714 0.71428571
#  0.68571429 0.65714286 0.62857143 0.6        0.57142857 0.54285714
# ...

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
print("Solution 14")

fig = plt.figure(figsize=(10, 6))
def plot_roc_curve(fpr, tpr, label=None): 
    plt.plot(fpr, tpr, color='darkorange', linewidth=8, label=label) 
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.axis([0, 1, 0, 1])
    plt.title('ROC Curve (Train Data)')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')

plot_roc_curve(fpr, tpr)
plt.show()
# Out:
# Solution 14
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ffd6ccb0e0d0> in <module>
#      12     plt.ylabel('True Positive Rate')
#      13
# ---> 14 plot_roc_curve(fpr, tpr)
#      15 plt.show()
#
# NameError: name 'fpr' is not defined

# %%
# Area under ROC curve
from sklearn.metrics import roc_auc_score
print("Solution 15")
print("Area under ROC curve : ",roc_auc_score(y_train,y_scores))
# Out:
# Solution 15
# Area under ROC curve :  0.7915851272015655

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# Get the 2nd column of the matrix of predicted probabilities for each data point
#    The 2nd column stores the probalities of the positive class
y_scores = cross_val_predict(knn, X_train, y_train, method="predict_proba", cv=10)[:, 1]

precisions, recalls, thresholds = precision_recall_curve(y_train, y_scores)

print("Solution 16")

fig = plt.figure(figsize=(10, 6))
def plot_precision_recall_vs_threshold(precisions, recalls, thresholds): 
    plt.plot(thresholds, precisions[:-1], "b--",  linewidth=8, label="Precision") 
    plt.plot(thresholds, recalls[:-1], "g-",  linewidth=3, label="Recall") 
    plt.xlabel("Threshold")
    plt.legend(loc="lower right")
    plt.title('Precision-Recall Curve')
    #plt.xlim([0, 1])
    plt.ylim([0, 1.1])

plot_precision_recall_vs_threshold(precisions, recalls, thresholds)
plt.show()
# Out:
# Solution 16

# %%
#From the graph, since we need a tradeoff between precision and recall, the optimum threshold is considered 0.6, where the two graphs cross paths.

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

print("Performance Measures Based on the Default Threshold:\n")


y_train_pred = cross_val_predict(knn, X_train, y_train, cv=10)

# Precision, Recall, F1 Score and Confusion Matrix for the Default Threshold 0.5
precision_train = precision_score(y_train, y_train_pred) 
print("Precision (Default Threshold 0.5) = %f" % precision_train)

recall_train = recall_score(y_train, y_train_pred)
print("Recall (Default Threshold 0.5) = %f" % recall_train)


f1_train = f1_score(y_train, y_train_pred)
print("F1 Score (Default Threshold 0.5) = %f" % f1_train)

print("Confusion Matrix (Default Threshold 0.5)\n", confusion_matrix(y_train, y_train_pred))


print("\n-------------------------------------------------------\n")
print("Performance Measures Based on New Threshold:")

# Precision, Recall, F1 Score and Confusion Matrix for different threshold

t = 0.6 # threshold 

# Compute predictions based on new t by using the following method:
#  - Get the probability of the positive class from the 2nd column [:, 1]
#  - If that probability is greater than or equal to t, then the test data belongs to the positive class
y_train_predicted_new = (cross_val_predict(knn, X_train, y_train, method="predict_proba", cv=10)[:,1] > t).astype(int)


precision = precision_score(y_train, y_train_predicted_new) 
print("\nPrecision (Threshold %.2f) = %f" % (t, precision))

recall = recall_score(y_train, y_train_predicted_new)
print("Recall (Threshold %.2f) = %f" % (t, recall))


f1 = f1_score(y_train, y_train_predicted_new)
print("F1 Score = (Threshold %.2f) = %f" % (t, f1))


print("Confusion Matrix (Threshold %.2f)" %  t) 
print(confusion_matrix(y_train, y_train_predicted_new))
# Out:
# Performance Measures Based on the Default Threshold:
#
# Precision (Default Threshold 0.5) = 0.768212
# Recall (Default Threshold 0.5) = 0.882801
# F1 Score (Default Threshold 0.5) = 0.821530
# Confusion Matrix (Default Threshold 0.5)
#  [[147 175]
#  [ 77 580]]
#
# -------------------------------------------------------
#
# Performance Measures Based on New Threshold:
#
# Precision (Threshold 0.60) = 0.817734
# Recall (Threshold 0.60) = 0.757991
# F1 Score = (Threshold 0.60) = 0.786730
# Confusion Matrix (Threshold 0.60)
# [[211 111]
#  [159 498]]

# %%
# The accuracy of the model
print("Solution 18")

score = knn.score(X_test, y_test)
print("Accuracy: %f" % score)

# No. of Correct Predictions
y_test_predicted = knn.predict(X_test)
print("\nNo. of correct predictions (Test): %d/%d" % (np.sum(y_test_predicted == y_test), len(y_test)))



# Confusion Matrix
print("\nConfusion Matrix (Test Data):\n", confusion_matrix(y_test, y_test_predicted))
# Out:
# Solution 18
# Accuracy: 0.730544
#
# No. of correct predictions (Test): 2863/3919
#
# Confusion Matrix (Test Data):
#  [[ 556  762]
#  [ 294 2307]]

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

print("Solution 18")
precision = precision_score(y_test, y_test_predicted) 
print("Precision = %f" % precision)

recall = recall_score(y_test, y_test_predicted)
print("Recall = %f" % recall)


f1 = f1_score(y_test, y_test_predicted)
print("F1 Score = %f" % f1)
# Out:
# Solution 18
# Precision = 0.751711
# Recall = 0.886967
# F1 Score = 0.813757

# %%
# For the question 7, I have experimented by dropping the redundant values as well as not dropping them. The values obtined for precision, Recall and F1 score are exactly the same. So, it is better that we drop the redundant feature.
