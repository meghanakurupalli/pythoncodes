# %%
import pandas as pd
df= pd.read_csv('OnlineNewsPopularity.csv')

# %%
df.head()
# Out:
#                                                  url   timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...       731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...       731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...       731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/       731.0
#
#     n_tokens_title   n_tokens_content   n_unique_tokens   n_non_stop_words  \
# 0             12.0              219.0          0.663594                1.0
# 1              9.0              255.0          0.604743                1.0
# 2              9.0              211.0          0.575130                1.0
# 3              9.0              531.0          0.503788                1.0
# 4             13.0             1072.0          0.415646                1.0
#
#     n_non_stop_unique_tokens   num_hrefs   num_self_hrefs   num_imgs   ...     \
# 0                   0.815385         4.0              2.0        1.0   ...
# 1                   0.791946         3.0              1.0        1.0   ...
# 2                   0.663866         3.0              1.0        1.0   ...
# 3                   0.665635         9.0              0.0        1.0   ...
# 4                   0.540890        19.0             19.0       20.0   ...
#
#     min_positive_polarity   max_positive_polarity   avg_negative_polarity  \
# 0                0.100000                     0.7               -0.350000
# 1                0.033333                     0.7               -0.118750
# 2                0.100000                     1.0               -0.466667
# 3                0.136364                     0.8               -0.369697
# 4                0.033333                     1.0               -0.220192
#
#     min_negative_polarity   max_negative_polarity   title_subjectivity  \
# 0                  -0.600               -0.200000             0.500000
# 1                  -0.125               -0.100000             0.000000
# 2                  -0.800               -0.133333             0.000000
# 3                  -0.600               -0.166667             0.000000
# 4                  -0.500               -0.050000             0.454545
#
#     title_sentiment_polarity   abs_title_subjectivity  \
# 0                  -0.187500                 0.000000
# 1                   0.000000                 0.500000
# 2                   0.000000                 0.500000
# 3                   0.000000                 0.500000
# 4                   0.136364                 0.045455
#
#     abs_title_sentiment_polarity   shares
# 0                       0.187500      593
# 1                       0.000000      711
# 2                       0.000000     1500
# 3                       0.000000     1200
# 4                       0.136364      505
#
# [5 rows x 61 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39644 entries, 0 to 39643
# Data columns (total 61 columns):
# url                               39644 non-null object
#  timedelta                        39644 non-null float64
#  n_tokens_title                   39644 non-null float64
#  n_tokens_content                 39644 non-null float64
#  n_unique_tokens                  39644 non-null float64
#  n_non_stop_words                 39644 non-null float64
#  n_non_stop_unique_tokens         39644 non-null float64
#  num_hrefs                        39644 non-null float64
#  num_self_hrefs                   39644 non-null float64
#  num_imgs                         39644 non-null float64
#  num_videos                       39644 non-null float64
#  average_token_length             39644 non-null float64
#  num_keywords                     39644 non-null float64
#  data_channel_is_lifestyle        39644 non-null float64
#  data_channel_is_entertainment    39644 non-null float64
#  data_channel_is_bus              39644 non-null float64
#  data_channel_is_socmed           39644 non-null float64
#  data_channel_is_tech             39644 non-null float64
#  data_channel_is_world            39644 non-null float64
#  kw_min_min                       39644 non-null float64
#  kw_max_min                       39644 non-null float64
#  kw_avg_min                       39644 non-null float64
#  kw_min_max                       39644 non-null float64
#  kw_max_max                       39644 non-null float64
#  kw_avg_max                       39644 non-null float64
#  kw_min_avg                       39644 non-null float64
#  kw_max_avg                       39644 non-null float64
#  kw_avg_avg                       39644 non-null float64
#  self_reference_min_shares        39644 non-null float64
#  self_reference_max_shares        39644 non-null float64
#  self_reference_avg_sharess       39644 non-null float64
#  weekday_is_monday                39644 non-null float64
#  weekday_is_tuesday               39644 non-null float64
#  weekday_is_wednesday             39644 non-null float64
#  weekday_is_thursday              39644 non-null float64
#  weekday_is_friday                39644 non-null float64
#  weekday_is_saturday              39644 non-null float64
#  weekday_is_sunday                39644 non-null float64
#  is_weekend                       39644 non-null float64
#  LDA_00                           39644 non-null float64
#  LDA_01                           39644 non-null float64
#  LDA_02                           39644 non-null float64
#  LDA_03                           39644 non-null float64
#  LDA_04                           39644 non-null float64
#  global_subjectivity              39644 non-null float64
#  global_sentiment_polarity        39644 non-null float64
#  global_rate_positive_words       39644 non-null float64
#  global_rate_negative_words       39644 non-null float64
#  rate_positive_words              39644 non-null float64
#  rate_negative_words              39644 non-null float64
#  avg_positive_polarity            39644 non-null float64
#  min_positive_polarity            39644 non-null float64
#  max_positive_polarity            39644 non-null float64
#  avg_negative_polarity            39644 non-null float64
#  min_negative_polarity            39644 non-null float64
#  max_negative_polarity            39644 non-null float64
#  title_subjectivity               39644 non-null float64
#  title_sentiment_polarity         39644 non-null float64
#  abs_title_subjectivity           39644 non-null float64
#  abs_title_sentiment_polarity     39644 non-null float64
#  shares                           39644 non-null int64
# dtypes: float64(59), int64(1), object(1)
# memory usage: 18.5+ MB

# %%
print("Dimension of the data: ", df.shape)
no_of_rows=df.shape[0]
no_of_columns=df.shape[1]

print("No. of Rows %d" % no_of_rows)
print("No. of Columns: %d" % no_of_columns)
# Out:
# Dimension of the data:  (39644, 61)
# No. of Rows 39644
# No. of Columns: 61

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

df.hist(bins=50, figsize=(30,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000019F396FAF28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38AE2390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3520C710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F35CD3C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F396A1278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38B05518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38752128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38BE4F28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38BE4F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38BFDA20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38C07F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38C16550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38C22AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38C37080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38C525F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F397C6780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38C76CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38C9C2B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38CBE828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38CDFDA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38D04358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38D2C8D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38D53E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38D83400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38DAB978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38DD5EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38E054A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38E2DA20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38E56F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38E86550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38EAFAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38EE1080>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38F085F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38F2FB70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38F60128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38F896A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38FAFC18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F38FDF1D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F39009748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F39031CC0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019F39062278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3908C7F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F390B3D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F390E6320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3910B898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F39135E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F391643C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3918A940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019F391B6EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F39FA6470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F39FCB9E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F39FF5F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3A025518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3A04BA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3A081048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3A0A75C0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3A0CFB38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3A1020F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3A12A668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3A152BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3A184198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3A1AB710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3A1D2C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3A202240>]],
#       dtype=object)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df[' shares'].hist(bins=50, figsize=(10,5))

# %%
df.describe()
# Out:
#           timedelta   n_tokens_title   n_tokens_content   n_unique_tokens  \
# count  39644.000000     39644.000000       39644.000000      39644.000000
# mean     354.530471        10.398749         546.514731          0.548216
# std      214.163767         2.114037         471.107508          3.520708
# min        8.000000         2.000000           0.000000          0.000000
# 25%      164.000000         9.000000         246.000000          0.470870
# 50%      339.000000        10.000000         409.000000          0.539226
# 75%      542.000000        12.000000         716.000000          0.608696
# max      731.000000        23.000000        8474.000000        701.000000
#
#         n_non_stop_words   n_non_stop_unique_tokens     num_hrefs  \
# count       39644.000000               39644.000000  39644.000000
# mean            0.996469                   0.689175     10.883690
# std             5.231231                   3.264816     11.332017
# min             0.000000                   0.000000      0.000000
# 25%             1.000000                   0.625739      4.000000
# 50%             1.000000                   0.690476      8.000000
# 75%             1.000000                   0.754630     14.000000
# max          1042.000000                 650.000000    304.000000
#
#         num_self_hrefs      num_imgs    num_videos      ...        \
# count     39644.000000  39644.000000  39644.000000      ...
# mean          3.293638      4.544143      1.249874      ...
# std           3.855141      8.309434      4.107855      ...
# min           0.000000      0.000000      0.000000      ...
# 25%           1.000000      1.000000      0.000000      ...
# 50%           3.000000      1.000000      0.000000      ...
# 75%           4.000000      4.000000      1.000000      ...
# max         116.000000    128.000000     91.000000      ...
#
#         min_positive_polarity   max_positive_polarity   avg_negative_polarity  \
# count            39644.000000            39644.000000            39644.000000
# mean                 0.095446                0.756728               -0.259524
# std                  0.071315                0.247786                0.127726
# min                  0.000000                0.000000               -1.000000
# 25%                  0.050000                0.600000               -0.328383
# 50%                  0.100000                0.800000               -0.253333
# 75%                  0.100000                1.000000               -0.186905
# max                  1.000000                1.000000                0.000000
#
#         min_negative_polarity   max_negative_polarity   title_subjectivity  \
# count            39644.000000            39644.000000         39644.000000
# mean                -0.521944               -0.107500             0.282353
# std                  0.290290                0.095373             0.324247
# min                 -1.000000               -1.000000             0.000000
# 25%                 -0.700000               -0.125000             0.000000
# 50%                 -0.500000               -0.100000             0.150000
# 75%                 -0.300000               -0.050000             0.500000
# max                  0.000000                0.000000             1.000000
#
#         title_sentiment_polarity   abs_title_subjectivity  \
# count               39644.000000             39644.000000
# mean                    0.071425                 0.341843
# std                     0.265450                 0.188791
# min                    -1.000000                 0.000000
# 25%                     0.000000                 0.166667
# 50%                     0.000000                 0.500000
# 75%                     0.150000                 0.500000
# max                     1.000000                 0.500000
#
#         abs_title_sentiment_polarity         shares
# count                   39644.000000   39644.000000
# mean                        0.156064    3395.380184
# std                         0.226294   11626.950749
# min                         0.000000       1.000000
# 25%                         0.000000     946.000000
# 50%                         0.000000    1400.000000
# 75%                         0.250000    2800.000000
# max                         1.000000  843300.000000
#
# [8 rows x 60 columns]

# %%
for i in range(5):
    print('\nColumn Name:', df.columns[i],)
    print(df[df.columns[i]].value_counts())
# Out:
# Column Name: url
# http://mashable.com/2013/12/03/motorola-apologizes-for-cyber-monday-mess-adds-two-more-days-of-deals/    1
# http://mashable.com/2013/05/23/life-before-smartphones/                                                  1
# http://mashable.com/2014/07/10/australia-gift-world-leaders/                                             1
# http://mashable.com/2014/07/15/beach-top-vacation-destination/                                           1
# http://mashable.com/2013/11/13/amazon-brings-kindle-store-kindle-fire-hd-and-hdx-to-australia/           1
# http://mashable.com/2013/05/07/pebble-runkeeper/                                                         1
# http://mashable.com/2013/07/03/pinterest-ideas-july-4/                                                   1
# http://mashable.com/2014/09/08/adobe-mobile-benchmark-report/                                            1
# http://mashable.com/2014/12/14/mistletoe-kissing-contraption/                                            1
# http://mashable.com/2014/09/30/jeff-goldblum-ge-commercial/                                              1
# http://mashable.com/2014/12/05/joan-rivers-grammy-nominee-nomination/                                    1
# http://mashable.com/2013/02/13/buzzword-valentines/                                                      1
# http://mashable.com/2014/12/03/david-cameron-masosadism/                                                 1
# http://mashable.com/2014/09/23/samsung-galaxy-note-early-launch/                                         1
# http://mashable.com/2014/12/23/syria-rubble/                                                             1
# http://mashable.com/2013/09/20/apple-iphone-lines/                                                       1
# http://mashable.com/2014/04/16/ukrainian-fighter-jet-russian-separatists/                                1
# http://mashable.com/2014/06/29/mexico-netherlands-world-cup-robben/                                      1
# http://mashable.com/2014/09/23/microsoft-display-adpater/                                                1
# http://mashable.com/2014/04/30/soccer-anti-racism-bananas-neymar-alves/                                  1
# http://mashable.com/2014/08/26/california-kill-switch-law/                                               1
# http://mashable.com/2013/06/04/citizen-cosponsor/                                                        1
# http://mashable.com/2014/01/10/aquarium-engagement-photo/                                                1
# http://mashable.com/2014/03/17/fred-phelps-westboro-baptist-church/                                      1
# http://mashable.com/2013/05/13/snow-white-dwarfs/                                                        1
# http://mashable.com/2014/02/28/best-picture-musicals/                                                    1
# http://mashable.com/2013/11/30/black-friday-vines/                                                       1
# http://mashable.com/2014/08/13/gmail-phishing-filters/                                                   1
# http://mashable.com/2014/01/06/snapchat-hires-washington-lobbying-firm/                                  1
# http://mashable.com/2013/10/09/guardian-kids-wearable/                                                   1
#                                                                                                         ..
# http://mashable.com/2013/03/17/wine-ecommerce/                                                           1
# http://mashable.com/2014/05/07/brazil-world-cup-roster/                                                  1
# http://mashable.com/2014/10/27/managing-shy-employee/                                                    1
# http://mashable.com/2014/10/16/ebola-panic-fueling-rise-in-alarmist-products/                            1
# http://mashable.com/2013/01/28/barnes-and-noble-closing-stores/                                          1
# http://mashable.com/2014/11/20/obama-immigration-overhaul/                                               1
# http://mashable.com/2013/05/27/social-media-advice-column-5-27/                                          1
# http://mashable.com/2014/11/27/amsterdam-tourist-deaths/                                                 1
# http://mashable.com/2013/05/06/viral-video-recap-28/                                                     1
# http://mashable.com/2014/11/07/parody-amazon-echo/                                                       1
# http://mashable.com/2014/01/19/linkedin-groups-3/                                                        1
# http://mashable.com/2013/09/17/linkedin-data-requests-challenge/                                         1
# http://mashable.com/2013/05/10/worst-rooms-tumblr/                                                       1
# http://mashable.com/2014/10/09/ebola-travel-ban-survey/                                                  1
# http://mashable.com/2014/01/22/obalon-weight-loss/                                                       1
# http://mashable.com/2013/03/19/cuddly-elephant/                                                          1
# http://mashable.com/2013/05/13/what-to-expect-blackberry-live/                                           1
# http://mashable.com/2013/05/07/pistol-annies-adventure-annie-up-album/                                   1
# http://mashable.com/2013/11/15/harry-potter-actors-then-and-now/                                         1
# http://mashable.com/2013/05/01/tim-cook-d11/                                                             1
# http://mashable.com/2014/11/21/event-planning-technology/                                                1
# http://mashable.com/2014/04/23/nyc-flood-risk/                                                           1
# http://mashable.com/2014/04/12/watch-a-cute-video-help-a-dog-in-need/                                    1
# http://mashable.com/2013/06/07/lakers-fans-nba-finals-kimmel/                                            1
# http://mashable.com/2013/02/13/digital-love-tips/                                                        1
# http://mashable.com/2013/06/12/dennys-nsa-tweet/                                                         1
# http://mashable.com/2014/02/05/cvs-will-no-longer-sell-cigarettes/                                       1
# http://mashable.com/2014/10/15/immortals-fall-out-boy-disney/                                            1
# http://mashable.com/2013/02/11/report-twitter-now-charges-200000-for-promoted-trends/                    1
# http://mashable.com/2014/02/05/moon-necessity-planet-life/                                               1
# Name: url, Length: 39644, dtype: int64
#
# Column Name:  timedelta
# 91.0     104
# 72.0     102
# 84.0     101
# 59.0      99
# 29.0      99
# 210.0     97
# 182.0     96
# 28.0      95
# 37.0      95
# 127.0     94
# 161.0     94
# 52.0      94
# 77.0      93
# 79.0      93
# 35.0      93
# 23.0      93
# 100.0     92
# 36.0      92
# 66.0      92
# 92.0      92
# 71.0      91
# 49.0      90
# 135.0     90
# 169.0     90
# 126.0     90
# 121.0     90
# 260.0     89
# 64.0      89
# 50.0      89
# 729.0     89
#         ...
# 522.0     19
# 481.0     19
# 256.0     19
# 243.0     19
# 145.0     19
# 495.0     19
# 432.0     19
# 677.0     19
# 264.0     19
# 383.0     19
# 557.0     19
# 621.0     19
# 691.0     18
# 404.0     18
# 299.0     18
# 508.0     18
# 494.0     18
# 684.0     18
# 585.0     18
# 705.0     17
# 719.0     17
# 571.0     17
# 369.0     17
# 635.0     16
# 291.0     16
# 375.0     15
# 656.0     15
# 376.0     15
# 730.0     12
# 8.0        8
# Name:  timedelta, Length: 724, dtype: int64
#
# Column Name:  n_tokens_title
# 10.0    7358
# 11.0    6960
# 9.0     6278
# 12.0    5299
# 8.0     4227
# 13.0    3509
# 7.0     2120
# 14.0    1733
# 6.0      805
# 15.0     756
# 16.0     259
# 5.0      184
# 17.0      91
# 4.0       28
# 18.0      22
# 19.0       6
# 3.0        5
# 20.0       2
# 2.0        1
# 23.0       1
# Name:  n_tokens_title, dtype: int64
#
# Column Name:  n_tokens_content
# 0.0       1181
# 286.0      101
# 335.0       86
# 225.0       86
# 279.0       85
# 242.0       84
# 301.0       82
# 246.0       80
# 258.0       80
# 232.0       80
# 294.0       80
# 318.0       79
# 256.0       79
# 197.0       79
# 230.0       78
# 292.0       78
# 209.0       78
# 315.0       78
# 276.0       78
# 281.0       78
# 317.0       78
# 303.0       77
# 223.0       76
# 263.0       76
# 299.0       76
# 235.0       76
# 190.0       76
# 327.0       75
# 240.0       75
# 184.0       75
#           ...
# 2718.0       1
# 3076.0       1
# 1775.0       1
# 1842.0       1
# 3774.0       1
# 2305.0       1
# 2844.0       1
# 3113.0       1
# 2635.0       1
# 2328.0       1
# 7002.0       1
# 1989.0       1
# 1888.0       1
# 2578.0       1
# 1919.0       1
# 2249.0       1
# 1923.0       1
# 3309.0       1
# 1268.0       1
# 3751.0       1
# 2170.0       1
# 2636.0       1
# 2662.0       1
# 2016.0       1
# 1944.0       1
# 2936.0       1
# 1892.0       1
# 1819.0       1
# 2651.0       1
# 3086.0       1
# Name:  n_tokens_content, Length: 2406, dtype: int64
#
# Column Name:  n_unique_tokens
# 0.000000    1181
# 0.666667      10
# 0.552083       9
# 0.740157       8
# 0.642512       8
# 0.640394       8
# 0.656977       8
# 0.649746       8
# 0.653846       8
# 0.674757       8
# 0.648780       8
# 0.613475       8
# 0.694805       8
# 0.618110       8
# 0.623529       8
# 0.636364       8
# 0.727941       7
# 0.601695       7
# 0.571429       7
# 0.651429       7
# 0.618123       7
# 0.647059       7
# 0.643519       7
# 0.621399       7
# 0.715447       7
# 0.565543       7
# 0.666667       7
# 0.685185       7
# 0.697987       7
# 0.602459       7
#             ...
# 0.558376       1
# 0.538860       1
# 0.576826       1
# 0.448224       1
# 0.730964       1
# 0.475738       1
# 0.493827       1
# 0.545272       1
# 0.510092       1
# 0.496523       1
# 0.449883       1
# 0.443539       1
# 0.416159       1
# 0.541401       1
# 0.536585       1
# 0.518883       1
# 0.444097       1
# 0.495633       1
# 0.346310       1
# 0.650442       1
# 0.518724       1
# 0.485616       1
# 0.506390       1
# 0.520309       1
# 0.494215       1
# 0.370855       1
# 0.535179       1
# 0.472340       1
# 0.535714       1
# 0.464286       1
# Name:  n_unique_tokens, Length: 27281, dtype: int64

# %%
df[' shares']
# Out:
# 0          593
# 1          711
# 2         1500
# 3         1200
# 4          505
# 5          855
# 6          556
# 7          891
# 8         3600
# 9          710
# 10        2200
# 11        1900
# 12         823
# 13       10000
# 14         761
# 15        1600
# 16       13600
# 17        3100
# 18        5700
# 19       17100
# 20        2800
# 21         598
# 22         445
# 23        1500
# 24         852
# 25         783
# 26        1500
# 27        1800
# 28         462
# 29         425
#          ...
# 39614     1400
# 39615     5700
# 39616     2100
# 39617      691
# 39618     1400
# 39619     1200
# 39620     2400
# 39621    24300
# 39622     2900
# 39623      947
# 39624     3200
# 39625     1400
# 39626     1100
# 39627     1200
# 39628     1000
# 39629     2400
# 39630     1500
# 39631      914
# 39632     1700
# 39633     1500
# 39634     1000
# 39635     1300
# 39636     1700
# 39637     1400
# 39638     1200
# 39639     1800
# 39640     1900
# 39641     1900
# 39642     1100
# 39643     1300
# Name:  shares, Length: 39644, dtype: int64

# %%
count = 0

def zeroCount(dataFrame, columnName):
    noOfZeros = 0
    for i in range(dataFrame.shape[0]):
        if dataFrame[columnName][i] == 0:
            noOfZeros = noOfZeros + 1
    return noOfZeros

count = zeroCount(df, ' num_videos')

print("Number of 0s in the Target Column: %d" % count)
# Out:
# Number of 0s in the Target Column: 25026

# %%
df =df[df[' num_videos']>0]

# %%
df[' num_videos']
# Out:
# 9         1.0
# 13       21.0
# 16        1.0
# 21        1.0
# 30        1.0
# 37        1.0
# 39        1.0
# 47        6.0
# 50        1.0
# 59        1.0
# 66        1.0
# 76        1.0
# 77        1.0
# 88        1.0
# 99       11.0
# 100       1.0
# 110       1.0
# 112       1.0
# 113       1.0
# 123       1.0
# 126      11.0
# 129       3.0
# 135       1.0
# 136       1.0
# 137       1.0
# 145       1.0
# 152       1.0
# 168       1.0
# 176       1.0
# 181      16.0
#          ...
# 39564     1.0
# 39569     1.0
# 39574     1.0
# 39575     6.0
# 39576     1.0
# 39578     1.0
# 39584     1.0
# 39585     1.0
# 39587     1.0
# 39592     1.0
# 39593     1.0
# 39595     1.0
# 39596     1.0
# 39597     1.0
# 39598     1.0
# 39600     8.0
# 39601     1.0
# 39604     1.0
# 39612     1.0
# 39615     1.0
# 39616     1.0
# 39625     1.0
# 39626     1.0
# 39629     2.0
# 39630     1.0
# 39634     2.0
# 39639     1.0
# 39640    48.0
# 39641     1.0
# 39643     2.0
# Name:  num_videos, Length: 14618, dtype: float64

# %%
newCount = 0

def zeroCount(dataFrame, columnName):
    noOfZeros = 0
    for i in range(len(dataFrame.index.get_values())):
        if dataFrame[columnName][dataFrame.index.get_values()[i]] == 0:
            noOfZeros = noOfZeros + 1
    return noOfZeros

newCount = zeroCount(df, ' num_videos')

print("Number of 0s in the Target Column: %d" % newCount)
# Out:
# Number of 0s in the Target Column: 0

# %%
df = df.rename(columns={' num_imgs': ' num_images'})

df.head()
# Out:
#                                                   url   timedelta  \
# 9   http://mashable.com/2013/01/07/chuck-hagel-web...       731.0
# 13          http://mashable.com/2013/01/07/dad-jokes/       731.0
# 16          http://mashable.com/2013/01/07/echo-game/       731.0
# 21   http://mashable.com/2013/01/07/ftc-google-leaks/       731.0
# 30  http://mashable.com/2013/01/07/land-a-job-at-s...       731.0
#
#      n_tokens_title   n_tokens_content   n_unique_tokens   n_non_stop_words  \
# 9              10.0              231.0          0.636364                1.0
# 13              9.0              285.0          0.744186                1.0
# 16              8.0             1118.0          0.512397                1.0
# 21              9.0              391.0          0.510256                1.0
# 30              8.0              708.0          0.482219                1.0
#
#      n_non_stop_unique_tokens   num_hrefs   num_self_hrefs   num_images  \
# 9                    0.797101         4.0              1.0          1.0
# 13                   0.841530         4.0              2.0          0.0
# 16                   0.709770        26.0             18.0         12.0
# 21                   0.650000         9.0              2.0          1.0
# 30                   0.688119         8.0              3.0          1.0
#
#      ...      min_positive_polarity   max_positive_polarity  \
# 9    ...                       0.10                    0.50
# 13   ...                       0.16                    1.00
# 16   ...                       0.10                    1.00
# 21   ...                       0.05                    0.35
# 30   ...                       0.10                    1.00
#
#      avg_negative_polarity   min_negative_polarity   max_negative_polarity  \
# 9                -0.238095               -0.500000                   -0.10
# 13               -0.337889               -0.700000                   -0.10
# 16               -0.401437               -1.000000                   -0.05
# 21               -0.108333               -0.166667                   -0.05
# 30               -0.244444               -0.500000                   -0.05
#
#      title_subjectivity   title_sentiment_polarity   abs_title_subjectivity  \
# 9              0.000000                        0.0                 0.500000
# 13             1.000000                       -1.0                 0.500000
# 16             0.566667                       -0.1                 0.066667
# 21             0.000000                        0.0                 0.500000
# 30             0.000000                        0.0                 0.500000
#
#      abs_title_sentiment_polarity   shares
# 9                             0.0      710
# 13                            1.0    10000
# 16                            0.1    13600
# 21                            0.0      598
# 30                            0.0     3200
#
# [5 rows x 61 columns]

# %%
df['Grade'].describe()
# Out:
# count    14618.000000
# mean         3.389657
# std          6.205796
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max         91.000000
# Name: Grade, dtype: float64

# %%
# Import Matplotlib for plotting
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['font.size'] = 16
plt.rcParams['figure.figsize'] = (9, 9)

# Bar plot of grades
plt.bar(df['Grade'].value_counts().index, 
        df['Grade'].value_counts().values,
         fill = 'navy', edgecolor = 'k', width = 1)
plt.xlabel('Grade'); 
plt.ylabel('Count'); 
plt.title('Distribution of Final Total');
plt.xticks(list(range(5, 20)));

# %%
# Scipy helper functions
from scipy.stats import percentileofscore


# Calculate percentile for grades
df['percentile'] = df['Grade'].apply(lambda x: percentileofscore(df['Grade'], x))

# Plot percentiles for grades
plt.figure(figsize = (8, 6))

plt.plot(df['Grade'], df['percentile'], 'o')

plt.xticks(range(0, 20, 2), range(0, 20, 2))

plt.xlabel('Score'); 
plt.ylabel('Percentile'); 
plt.title('Grade Percentiles');

# %%
# Variable Correlations with Final Grade

df.corr()['Grade'].sort_values(ascending=False)
# Out:
# Grade                             1.000000
# percentile                        0.673345
#  global_rate_negative_words       0.255562
#  LDA_03                           0.239277
#  max_positive_polarity            0.221044
#  num_hrefs                        0.218258
#  n_tokens_content                 0.189030
#  avg_positive_polarity            0.163901
#  global_rate_positive_words       0.150491
#  num_self_hrefs                   0.142995
#  global_subjectivity              0.129990
#  rate_negative_words              0.119075
#  data_channel_is_entertainment    0.117830
#  timedelta                        0.105143
#  self_reference_max_shares        0.090703
#  n_non_stop_words                 0.087630
#  kw_min_min                       0.083076
#  kw_avg_max                       0.077313
#  average_token_length             0.075893
#  kw_avg_avg                       0.064383
#  title_subjectivity               0.063249
#  abs_title_sentiment_polarity     0.062524
#  max_negative_polarity            0.054885
#  kw_min_avg                       0.054095
#  self_reference_avg_sharess       0.040739
#  kw_min_max                       0.040294
#  n_unique_tokens                  0.039251
#  n_non_stop_unique_tokens         0.038037
#  title_sentiment_polarity         0.036382
#  kw_max_avg                       0.021217
#                                     ...
#  weekday_is_monday                0.012801
#  n_tokens_title                   0.009067
#  weekday_is_saturday              0.007652
#  rate_positive_words              0.002305
#  weekday_is_friday                0.002187
#  shares                           0.001659
#  weekday_is_tuesday               0.000191
#  kw_max_min                      -0.001264
#  kw_avg_min                      -0.002517
#  weekday_is_thursday             -0.003544
#  weekday_is_wednesday            -0.004456
#  self_reference_min_shares       -0.004749
#  is_weekend                      -0.007933
#  global_sentiment_polarity       -0.012421
#  weekday_is_sunday               -0.017368
#  LDA_00                          -0.023648
#  data_channel_is_bus             -0.024395
#  LDA_01                          -0.025079
#  abs_title_subjectivity          -0.030444
#  min_positive_polarity           -0.031064
#  data_channel_is_lifestyle       -0.036906
#  num_keywords                    -0.059753
#  kw_max_max                      -0.077797
#  num_images                      -0.101335
#  data_channel_is_tech            -0.118072
#  LDA_02                          -0.119800
#  data_channel_is_world           -0.125225
#  LDA_04                          -0.143586
#  avg_negative_polarity           -0.156766
#  min_negative_polarity           -0.212557
# Name: Grade, Length: 61, dtype: float64

# %%
from pandas.tools.plotting import scatter_matrix


attributes = ["Grade", " shares", " abs_title_sentiment_polarity", " title_sentiment_polarity", " min_negative_polarity", " min_positive_polarity"," avg_positive_polarity", " rate_negative_words"]

scatter_matrix(df[attributes], figsize=(15, 12))
# Out:
# c:\users\megha\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3D3782E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3D3C9E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3D3B30F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3D3DD358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3D4035C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3D429828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3D455A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3D47CD30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3D47CD68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3D4DB208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3D503470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3D6AC6D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3D6D5940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3D700BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3D72AE10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3D75C0B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3D787320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3D7B1588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3D7D77F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3D802A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3D82CCC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3D854F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3EB961D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3EBC2438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3EBEA6A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3EC13908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3EC3DB70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3EC68DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3EC99080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3ECC22E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3ECED550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3ED167B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3ED3EA20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3ED69C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3ED91EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3EDC4198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3EDEF400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3EE17668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3EE418D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3EE6BB38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3EE95DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3EEC7048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3EEF12B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3EF1A518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3EF42780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3EF6B9E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3EF97C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3EFC0EB8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3EFF2160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3F01D3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3F046630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3F06E898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3F099B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3F0C5D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3F0EEFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3F120278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3F14A4E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3F170748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3F19A9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3F1C4C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3F1EEE80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3F8F0128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3F91A390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019F3F9445F8>]],
#       dtype=object)

# %%
df.plot(title="Scatter Plot", kind="scatter", x=" shares", y="Grade")

# %%
df[' is_weekend']=df[' is_weekend'].apply(lambda x:str(x))
df[' weekday_is_saturday']=df[' weekday_is_saturday'].apply(lambda x:str(x))
df[' weekday_is_sunday']=df[' weekday_is_sunday'].apply(lambda x:str(x))

# %%
# Select only categorical variables
category_df = df.select_dtypes(include=['object'])
category_df = category_df.drop('url', axis =1)
# One hot encode the variables
dummy_df = pd.get_dummies(category_df)
# Put the grade back in the dataframe
dummy_df['Grade']=df['Grade']
dummy_df.head()
# Out:
#      weekday_is_saturday_0.0   weekday_is_saturday_1.0  \
# 9                          1                         0
# 13                         1                         0
# 16                         1                         0
# 21                         1                         0
# 30                         1                         0
#
#      weekday_is_sunday_0.0   weekday_is_sunday_1.0   is_weekend_0.0  \
# 9                        1                       0                1
# 13                       1                       0                1
# 16                       1                       0                1
# 21                       1                       0                1
# 30                       1                       0                1
#
#      is_weekend_1.0  Grade
# 9                 0    1.0
# 13                0   21.0
# 16                0    1.0
# 21                0    1.0
# 30                0    1.0

# %%
dummy_df.corr()['Grade'].sort_values(ascending=False)
# Out:
# Grade                       1.000000
#  weekday_is_sunday_0.0      0.017368
#  is_weekend_0.0             0.007933
#  weekday_is_saturday_1.0    0.007652
#  weekday_is_saturday_0.0   -0.007652
#  is_weekend_1.0            -0.007933
#  weekday_is_sunday_1.0     -0.017368
# Name: Grade, dtype: float64

# %%
df = df.drop(labels = [ ' timedelta', ' n_tokens_title', ' n_tokens_content' ], axis = 1)

# %%
# Combine the one-hot coded categorical features with the numerical features
df = df.drop('url', axis =1)
df = pd.get_dummies(df)

# Find correlations with the Grade
# Note that we have considered the absolute values of the correlations
# This will help to identify the most correlated features 
most_correlated = df.corr().abs()['Grade'].sort_values(ascending=False)

# Maintain the top 7 most correlation features with Grade
most_correlated = most_correlated[:8]

print("Most Correlated Features:\n")
print(most_correlated)
# Out:
# Most Correlated Features:
#
# Grade                          1.000000
# percentile                     0.673345
#  global_rate_negative_words    0.255562
#  LDA_03                        0.239277
#  max_positive_polarity         0.221044
#  num_hrefs                     0.218258
#  min_negative_polarity         0.212557
#  n_tokens_content              0.189030
# Name: Grade, dtype: float64

# %%
# See the most correlated column names
print("Most Correlated Index: ", most_correlated.index)

# Edit the DataFrame to Contain Only the Most Correlated Features¶
df = df.ix[:, most_correlated.index]
df = df.drop(' num_hrefs', axis=1)

df.head()
# Out:
# Most Correlated Index:  Index(['Grade', 'percentile', ' global_rate_negative_words', ' LDA_03',
#        ' max_positive_polarity', ' num_hrefs', ' min_negative_polarity',
#        ' n_tokens_content'],
#       dtype='object')
# c:\users\megha\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """
#     Grade  percentile   global_rate_negative_words    LDA_03  \
# 9     1.0   32.439458                     0.030303  0.040001
# 13   21.0   96.760843                     0.052632  0.866499
# 16    1.0   32.439458                     0.025939  0.839742
# 21    1.0   32.439458                     0.005115  0.028574
# 30    1.0   32.439458                     0.015537  0.029484
#
#      max_positive_polarity   min_negative_polarity   n_tokens_content
# 9                     0.50               -0.500000              231.0
# 13                    1.00               -0.700000              285.0
# 16                    1.00               -1.000000             1118.0
# 21                    0.35               -0.166667              391.0
# 30                    1.00               -0.500000              708.0

# %%
import seaborn as sns
from scipy import stats

# Calculate correlation coefficient
def corrfunc(x, y, **kws):
    r, _ = stats.pearsonr(x, y)
    ax = plt.gca()
    ax.annotate("r = {:.2f}".format(r),
                xy=(.1, .6), xycoords=ax.transAxes,
               size = 24)
    
cmap = sns.cubehelix_palette(light=1, dark = 0.1,
                             hue = 0.5, as_cmap=True)

sns.set_context(font_scale=2)

# Pair grid set up
g = sns.PairGrid(df)

# Scatter plot on the upper triangle
g.map_upper(plt.scatter, s=10, color = 'red')

# Distribution on the diagonal
g.map_diag(sns.distplot, kde=False, color = 'red')

# Density Plot and Correlation coefficients on the lower triangle
g.map_lower(sns.kdeplot, cmap = cmap)
g.map_lower(corrfunc);

# %%
# It contains all attributes (all features and the target)
allData = df


y = df['Grade'] # 1D targer vector
X = df.drop('Grade', axis =1) # Data Matrix containing all features excluding the target

allData.head()
# Out:
#     Grade  percentile   global_rate_negative_words    LDA_03  \
# 9     1.0   32.439458                     0.030303  0.040001
# 13   21.0   96.760843                     0.052632  0.866499
# 16    1.0   32.439458                     0.025939  0.839742
# 21    1.0   32.439458                     0.005115  0.028574
# 30    1.0   32.439458                     0.015537  0.029484
#
#      max_positive_polarity   min_negative_polarity   n_tokens_content
# 9                     0.50               -0.500000              231.0
# 13                    1.00               -0.700000              285.0
# 16                    1.00               -1.000000             1118.0
# 21                    0.35               -0.166667              391.0
# 30                    1.00               -0.500000              708.0

# %%
from sklearn.model_selection import train_test_split


# Split into training/testing sets with 20% split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state=42)

# %%
# Calculate mae and rmse
def evaluate_predictions(predictions, true):
    mae = np.mean(abs(predictions - true))
    rmse = np.sqrt(np.mean((predictions - true) ** 2))
    
    return mae, rmse

# %%
# Naive baseline is the median

import numpy as np


median_pred = y_train.median()

print(median_pred)

median_preds = [median_pred for _ in range(len(y_test))]
true = y_test


# Display the naive baseline metrics
mb_mae, mb_rmse = evaluate_predictions(median_preds, true)
print('Median Baseline  MAE: {:.4f}'.format(mb_mae))
print('Median Baseline RMSE: {:.4f}'.format(mb_rmse))
# Out:
# 1.0
# Median Baseline  MAE: 2.1826
# Median Baseline RMSE: 6.0705

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Create linear regression object
model = LinearRegression()

# Train the model using the traing data and label
model.fit(X_train, y_train)

# The intercept
b = model.intercept_
print('Intercept: \n',b )

# The feature weights (coefficients) in an array
m = model.coef_
print('Coefficients: \n', m)


# Show the prediction formula with the intercept and feature weight values
print("\nPrediction Formula: ")
print(' y(predicted) = {0} +  x_1 * {1} +  x_2 * {2} + x_3 * {3} + x_4 * {4} + x_5 * {5} + x_6 * {6}'
      .format(b, m[0], m[1], m[2], m[3], m[4], m[5]))


# Make predictions using the test data
y_predicted = model.predict(X_test)


# RMSE of the model
print("\nMean squared error: %.2f"
      % mean_squared_error(y_test, y_predicted))


# Explained variance score: 1 is perfect prediction
print('\nCoefficient of determination r^2 variance score [1 is perfect prediction]: %.2f' % r2_score(y_test, y_predicted))
# Out:
# Intercept:
#  -6.930031808567138
# Coefficients:
#  [1.55083309e-01 6.43582770e+01 2.41911317e+00 4.66334228e-01
#  4.78838120e-01 1.09019001e-03]
#
# Prediction Formula:
#  y(predicted) = -6.930031808567138 +  x_1 * 0.155083309289679 +  x_2 * 64.35827701293192 + x_3 * 2.419113171521833 + x_4 * 0.46633422821048903 + x_5 * 0.4788381200772509 + x_6 * 0.0010901900144091314
#
# Mean squared error: 16.46
#
# Coefficient of determination r^2 variance score [1 is perfect prediction]: 0.49

# %%
import numpy as np

# Model Metrics
mae = np.mean(abs(y_predicted - y_test))
rmse = np.sqrt(np.mean((y_predicted - y_test) ** 2))

print("Linear Regression MAE: ", mae)
print("Linear Regression RMSE: ", rmse)


# Baseline Metrics
baseline = np.median(y_train)
baseline_mae = np.mean(abs(baseline - y_test))
baseline_rmse = np.sqrt(np.mean((baseline - y_test) ** 2))


print("\nBaseline MAE: ", baseline_mae)
print("Baseline RMSE: ", baseline_rmse)
# Out:
# Linear Regression MAE:  2.4485935677354544
# Linear Regression RMSE:  4.0565292409458475
#
# Baseline MAE:  2.182626538987688
# Baseline RMSE:  6.07054966106155
